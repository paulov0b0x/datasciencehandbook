# %% [markdown]
# ## Density and Contour Plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %% [markdown]
# ### Visualizing a Three-Dimensional Function

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='black')

# %%
# Press Tab to see all colormaps available
plt.cm.
# Out:
#   File "<ipython-input-8-6e7a0d074a32>", line 2
#     plt.cm.
#            ^
# SyntaxError: invalid syntax

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %%
# Changing colour steps to continous rather than discrete using plt.imshow()

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
          cmap='RdGy')
plt.colorbar()
# Removing aspect since deprecated
# plt.axis(aspect='image')

# %%
# Combining contour plot and image plot
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
          cmap='RdGy', alpha=0.5)
plt.colorbar()
